# %% [markdown]
# We look at the demonitization tweets dataset for extracting certain information.
#
# ### 1. Loading Data

# %%
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")
#Loading the dataset
df = pd.read_csv("Demonetization_tweets.csv",encoding='unicode_escape')

# Printing first 5 rows
df.head()
# Out:
#    Unnamed: 0                                               text
# 0           1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  RT @satishacharya: Reddy Wedding! @mail_today ...

# %%
len(df)
# Out:
# 14940

# %%
# Looking at some Tweets
for index, tweet in enumerate(df["text"][0:20]):
    print(index+1,".",tweet)
# Out:
# 1 . RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# 2 . RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# 3 . RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# 4 . RT @ANI_news: Gurugram (Haryana): Post office employees provide cash exchange to patients in hospitals #demonetization https://t.co/uGMxUP9
# 5 . RT @satishacharya: Reddy Wedding! @mail_today cartoon #demonetization #ReddyWedding https://t.co/u7gLNrq31F
# 6 . @DerekScissors1: Indias #demonetization: #Blackmoney a symptom, not the disease https://t.co/HSl6Ihj0Qe via @ambazaarmag
# 7 . RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# 8 . RT @Joydeep_911: Calling all Nationalists to join...
# Walk for #CorruptionFreeIndia and spread the benefits of #Demonetization among the mas
# 9 . RT @sumitbhati2002: Many opposition leaders are with @narendramodi on the #Demonetization
# And respect their decision,but support oppositio
# 10 . National reform now destroyed even the essence of sagan. Such instances urge giving #demonetization a second though https://t.co/eyySIREiUq
# 11 . Many opposition leaders are with @narendramodi on the #Demonetization
# And respect their decision,but support opposition just b'coz of party
# 12 . RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# 13 . @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders.
# 14 . RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# 15 . RT @sona2905: When I explained #Demonetization to myself and tried to put it down in my words which are not laced with any heavy technical
# 16 . RT @Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards
# 17 . RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# 18 . RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# 19 . RT @pGurus1: #Demonetization The co-operative banking sector in Kerala is as good as a tax haven. Is Kerala a Black Money HQ? https://t.co/
# 20 . RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th

# %% [markdown]
# ### 2. Data Pre-processing using Regex
#
# From the above, we can see we can do the following data pre-processing.
#
# 1. Remove the word RT
# 2. Remove & amp;
# 3. Remove the strings like U+... and ed
# 4. Remove other tweet references that has a https link

# %%
import re

# Removing RT from a single Tweet
text = "RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;"
clean_text = re.sub('RT ','', text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# Text after:
#  @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;

# %%
#replacing the amp symbol with & 

clean_text= re.sub('&amp;', '&', text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# Text after:
#  RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &

# %%
#Removing strings lik <U+...> and <ed>

text= "@Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders."

clean_text= re.sub('<U\+[a-zA-Z0-9]+>', '', text)
clean_text= re.sub('<ed>', '', clean_text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders.
# Text after:
#  @Jaggesh2 Bharat band on 28??Those who  are protesting #demonetization  are all different party leaders.

# %%
#Remove other tweet references that has an https link
text= '@DerekScissors1: Indias #demonetization: #Blackmoney a symptom, not the disease https://t.co/HSl6Ihj0Qe via @ambazaarmag'

clean_text= re.sub('https://[a-zA-Z0-9/.]+','', text)

print("Text before:\n", text)
print("Text after:\n", clean_text)
# Out:
# Text before:
#  @DerekScissors1: Indias #demonetization: #Blackmoney a symptom, not the disease https://t.co/HSl6Ihj0Qe via @ambazaarmag
# Text after:
#  @DerekScissors1: Indias #demonetization: #Blackmoney a symptom, not the disease  via @ambazaarmag

# %%
def preprocessing(text):
    #removing RT
    text= re.sub('RT ','', text)
    #removing &amp;
    text= re.sub('&amp;', '&', text)
    #Removing strings lik <U+...> and <ed>
    text= re.sub('<U\+[a-zA-Z0-9]+>', '', text)
    text= re.sub('<ed>', '', text)
    #Remove other tweet references that has an https link
    text= re.sub('https?://[a-zA-Z0-9/.]+','', text)
    
    return text

df['clean_text']= df['text'].apply(preprocessing)

# %%
df= df.drop('Unnamed: 0', axis=1)

# %% [markdown]
# #### Removing duplicate tweets
#
# It looks like there are quite a few duplicates in the dataset. Since we are trying to find the top 50 by count, we need to remove these duplicates. Otherwise, it may skew the result.

# %%
df[df[['text']].duplicated() == True]
# Out:
#                                                     text  \
# 16     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 19     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 20     RT @Hemant_80: Did you vote on #Demonetization...
# 21     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 22     RT @Atheist_Krishna: BEFORE and AFTER Gandhi j...
# ...                                                  ...
# 14929  RT @rahulroushan: Prohibition is Demonetizatio...
# 14930  RT @rahulroushan: Prohibition is Demonetizatio...
# 14931  RT @bharat_builder: Lol. Demonetization has fi...
# 14934  RT @Vidyut: How India became Bill Gates' guine...
# 14937  RT @bharat_builder: Lol. Demonetization has fi...
#
#                                               clean_text
# 16     @roshankar: Former FinSec, RBI Dy Governor, CB...
# 19     @roshankar: Former FinSec, RBI Dy Governor, CB...
# 20     @Hemant_80: Did you vote on #Demonetization on...
# 21     @roshankar: Former FinSec, RBI Dy Governor, CB...
# 22     @Atheist_Krishna: BEFORE and AFTER Gandhi ji h...
# ...                                                  ...
# 14929  @rahulroushan: Prohibition is Demonetization 2...
# 14930  @rahulroushan: Prohibition is Demonetization 2...
# 14931  @bharat_builder: Lol. Demonetization has fixed...
# 14934  @Vidyut: How India became Bill Gates' guinea p...
# 14937  @bharat_builder: Lol. Demonetization has fixed...
#
# [9793 rows x 2 columns]

# %% [markdown]
# Out of the 14k tweets, ~10k tweets need to be de-duplicated.

# %%
new_df= df.drop_duplicates(subset=['text', 'clean_text'],)

# %%
len(df), len(new_df)
# Out:
# (14940, 5147)

# %% [markdown]
# We now have 5.1k unique tweets for our analysis.
#
# ### Find top 50 mentions in the dataset (mentions in this dataset refers to the @s)

# %%
#Extracting the mentions
text= 'RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy'
mentions= re.findall('@[\w]+', text)
mentions
# Out:
# ['@Joydas']

# %%
new_df['mention']= new_df['clean_text'].apply(lambda x: re.findall('@[\w]+', x))
new_df
# Out:
#                                                     text  \
# 0      RT @rssurjewala: Critical question: Was PayTM ...
# 1      RT @Hemant_80: Did you vote on #Demonetization...
# 2      RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3      RT @ANI_news: Gurugram (Haryana): Post office ...
# 4      RT @satishacharya: Reddy Wedding! @mail_today ...
# ...                                                  ...
# 14933  @thehill To The Hill. Shame on you for your an...
# 14935  RT @saxenavishakha: Ghost of demonetization re...
# 14936  N d modi fans-d true nationalists of the count...
# 14938  RT @Stupidosaur: @Vidyut B team of BJP. CIA ba...
# 14939  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                                               clean_text  \
# 0      @rssurjewala: Critical question: Was PayTM inf...
# 1      @Hemant_80: Did you vote on #Demonetization on...
# 2      @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3      @ANI_news: Gurugram (Haryana): Post office emp...
# 4      @satishacharya: Reddy Wedding! @mail_today car...
# ...                                                  ...
# 14933  @thehill To The Hill. Shame on you for your an...
# 14935  @saxenavishakha: Ghost of demonetization retur...
# 14936  N d modi fans-d true nationalists of the count...
# 14938  @Stupidosaur: @Vidyut B team of BJP. CIA baby....
# 14939  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                              mention
# 0                     [@rssurjewala]
# 1                       [@Hemant_80]
# 2                       [@roshankar]
# 3                        [@ANI_news]
# 4      [@satishacharya, @mail_today]
# ...                              ...
# 14933                     [@thehill]
# 14935              [@saxenavishakha]
# 14936                             []
# 14938        [@Stupidosaur, @Vidyut]
# 14939                      [@Vidyut]
#
# [5147 rows x 3 columns]

# %%
new_df= new_df.reset_index().drop('index', axis=1)
new_df
# Out:
#                                                    text  \
# 0     RT @rssurjewala: Critical question: Was PayTM ...
# 1     RT @Hemant_80: Did you vote on #Demonetization...
# 2     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3     RT @ANI_news: Gurugram (Haryana): Post office ...
# 4     RT @satishacharya: Reddy Wedding! @mail_today ...
# ...                                                 ...
# 5142  @thehill To The Hill. Shame on you for your an...
# 5143  RT @saxenavishakha: Ghost of demonetization re...
# 5144  N d modi fans-d true nationalists of the count...
# 5145  RT @Stupidosaur: @Vidyut B team of BJP. CIA ba...
# 5146  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                                              clean_text  \
# 0     @rssurjewala: Critical question: Was PayTM inf...
# 1     @Hemant_80: Did you vote on #Demonetization on...
# 2     @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3     @ANI_news: Gurugram (Haryana): Post office emp...
# 4     @satishacharya: Reddy Wedding! @mail_today car...
# ...                                                 ...
# 5142  @thehill To The Hill. Shame on you for your an...
# 5143  @saxenavishakha: Ghost of demonetization retur...
# 5144  N d modi fans-d true nationalists of the count...
# 5145  @Stupidosaur: @Vidyut B team of BJP. CIA baby....
# 5146  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                             mention
# 0                    [@rssurjewala]
# 1                      [@Hemant_80]
# 2                      [@roshankar]
# 3                       [@ANI_news]
# 4     [@satishacharya, @mail_today]
# ...                             ...
# 5142                     [@thehill]
# 5143              [@saxenavishakha]
# 5144                             []
# 5145        [@Stupidosaur, @Vidyut]
# 5146                      [@Vidyut]
#
# [5147 rows x 3 columns]

# %%
mention_count= {}

for i in range(len(new_df)):
    for j in new_df.loc[i,'mention']:
        if j in mention_count:
            mention_count[j]+=1
        else:
            mention_count[j]=1

# %%
mention_df= pd.DataFrame({'Mention': list(mention_count.keys()), 'Count_of_Mentions':list(mention_count.values()) })
mention_df.sort_values(by='Count_of_Mentions', ascending= False).head(50)
# Out:
#                Mention  Count_of_Mentions
# 11       @narendramodi                337
# 416           @YouTube                143
# 38           @PMOIndia                103
# 107    @ArvindKejriwal                 84
# 29        @arunjaitley                 41
# 1052      @evanspiegel                 36
# 1097   @arvindsubraman                 35
# 149              @ndtv                 30
# 193               @RBI                 26
# 49       @timesofindia                 24
# 1075      @Stupidosaur                 24
# 66     @DasShaktikanta                 24
# 52          @BJP4India                 23
# 1309      @AnnieLowrey                 22
# 125        @OfficeOfRG                 22
# 35    @sardesairajdeep                 22
# 60      @ShashiTharoor                 21
# 223               @dna                 20
# 372      @TheDarjChron                 19
# 3            @ANI_news                 19
# 161    @MamataOfficial                 19
# 157        @IndiaToday                 18
# 334         @CNNnews18                 18
# 1145    @navkendar_IDC                 17
# 1224            @CGDev                 16
# 108     @AamAadmiParty                 16
# 119     @centerofright                 16
# 1050        @Memeghnad                 16
# 51     @TheOfficialSBI                 15
# 19            @Swamy39                 15
# 89           @jamewils                 14
# 1129    @postcard_news                 14
# 1554      @JPAL_Global                 13
# 109          @TimesNow                 12
# 505      @digvijaya_28                 12
# 354       @FinMinIndia                 12
# 456            @c0nvey                 12
# 168             @Paytm                 11
# 1123     @SushmaSwaraj                 10
# 87           @AmitShah                 10
# 502          @AnkitLal                 10
# 1616        @madmanweb                 10
# 277           @jairajp                 10
# 59          @sonunigam                 10
# 392             @dhume                 10
# 81         @ShefVaidya                 10
# 170            @Vidyut                  9
# 53          @RanaAyyub                  9
# 1400    @SpencerKarter                  9
# 36         @ravishndtv                  9

# %% [markdown]
# The above gives the top 50 mentions and their counts among the tweets.

# %% [markdown]
# ### Find the top 50 most frequently used hashtags (#)
#
# This is similar to the above task, with the key difference being, we will use # in the regex to find the hashtags

# %%
text= 'RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy'
hashtags= re.findall('#[\w]+', text)
hashtags
# Out:
# ['#DeMonetization']

# %%
new_df['hashtag']= new_df['clean_text'].apply(lambda x: re.findall('#[\w]+', x))
new_df
# Out:
#                                                    text  \
# 0     RT @rssurjewala: Critical question: Was PayTM ...
# 1     RT @Hemant_80: Did you vote on #Demonetization...
# 2     RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3     RT @ANI_news: Gurugram (Haryana): Post office ...
# 4     RT @satishacharya: Reddy Wedding! @mail_today ...
# ...                                                 ...
# 5142  @thehill To The Hill. Shame on you for your an...
# 5143  RT @saxenavishakha: Ghost of demonetization re...
# 5144  N d modi fans-d true nationalists of the count...
# 5145  RT @Stupidosaur: @Vidyut B team of BJP. CIA ba...
# 5146  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                                              clean_text  \
# 0     @rssurjewala: Critical question: Was PayTM inf...
# 1     @Hemant_80: Did you vote on #Demonetization on...
# 2     @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3     @ANI_news: Gurugram (Haryana): Post office emp...
# 4     @satishacharya: Reddy Wedding! @mail_today car...
# ...                                                 ...
# 5142  @thehill To The Hill. Shame on you for your an...
# 5143  @saxenavishakha: Ghost of demonetization retur...
# 5144  N d modi fans-d true nationalists of the count...
# 5145  @Stupidosaur: @Vidyut B team of BJP. CIA baby....
# 5146  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                             mention                           hashtag
# 0                    [@rssurjewala]                 [#Demonetization]
# 1                      [@Hemant_80]                 [#Demonetization]
# 2                      [@roshankar]                 [#Demonetization]
# 3                       [@ANI_news]                 [#demonetization]
# 4     [@satishacharya, @mail_today]  [#demonetization, #ReddyWedding]
# ...                             ...                               ...
# 5142                     [@thehill]                                []
# 5143              [@saxenavishakha]                                []
# 5144                             []                                []
# 5145        [@Stupidosaur, @Vidyut]                                []
# 5146                      [@Vidyut]                                []
#
# [5147 rows x 4 columns]

# %% [markdown]
# We notice that the hashtag for demonitization is available in both lower and sentence case. To get the top 50 hashtags, let's make the count case insensitive. This will give us a better picture of the topics being discussed through the hashtags.

# %%
hashtag_count= {}

for i in range(len(new_df)):
    for j in new_df.loc[i,'hashtag']:
        if j.lower() in hashtag_count: #taking lower case
            hashtag_count[j.lower()]+=1
        else:
            hashtag_count[j.lower()]=1

# %%
hashtag_df= pd.DataFrame({'Hashtag': list(hashtag_count.keys()), 'Count_of_Hashtag':list(hashtag_count.values()) })
hashtag_df.sort_values(by='Count_of_Hashtag', ascending= False).head(50)
# Out:
#                        Hashtag  Count_of_Hashtag
# 0              #demonetization              2889
# 29                      #india               165
# 2                  #blackmoney                73
# 87             #demonetisation                46
# 50                       #modi                46
# 6                #narendramodi                32
# 808                   #youtube                28
# 51                        #bjp                28
# 279                      #news                25
# 88                        #rbi                19
# 65                    #bypolls                19
# 920                  #cgdtalks                18
# 984                  #snapchat                18
# 314                 #northeast                17
# 116                       #atm                16
# 43                     #pmmodi                16
# 153                       #___                16
# 167                   #fintech                16
# 468                #realestate                15
# 221               #currencyban                14
# 211                   #digital                14
# 71                   #cashless                14
# 280                   #summary                14
# 339                      #bank                14
# 392                     #banks                13
# 411                  #payments                13
# 128                      #cash                13
# 118                   #noteban                13
# 178                 #jankibaat                12
# 257      #demonetizationeffect                12
# 120                     #delhi                12
# 180              #janjankibaat                12
# 23                #netascashin                12
# 166                  #startups                12
# 48                 #corruption                11
# 477      #modifightscorruption                11
# 908           #boycottsnapchat                11
# 509   #withdrawupto1000fromatm                11
# 177                #mannkibaat                11
# 8                      #survey                11
# 140                   #bitcoin                11
# 1177   #incrementpremierleague                10
# 101                     #paytm                10
# 1131                  #acjlive                10
# 904               #adsensegate                10
# 27                          #_                10
# 37                         #pm                 9
# 36                         #__                 9
# 825                       #ubi                 9
# 664               #kejrikajuth                 9

# %% [markdown]
# The above are the set of hashtags. It is overwhelmingly #demonetization.

# %% [markdown]
# ### Find the sentences having mentions of Prime Minister

# %%
def pm_mention(text):

    patterns = [r'(?i)prime minister',
               r'(?i)pm',
               r'(?i)modi',
              ]

    output = []
    flag = 0
    for pat in patterns:
        if re.search(pat, text) != None:
            flag = 1
            break
    return flag

# apply function
new_df['mentions_PM'] = new_df['clean_text'].apply(pm_mention)

# %% [markdown]
# We have created a pattern with different variations of references to the prime minister, such as pm, prime minister and modi. These are case insensitive and therefore will capture all such references. The column 'Mentions_PM' will be set to 1 if the respective tweet has reference to the Prime Minister.

# %%
new_df[new_df['mentions_PM']==1]
# Out:
#                                                    text  \
# 0     RT @rssurjewala: Critical question: Was PayTM ...
# 1     RT @Hemant_80: Did you vote on #Demonetization...
# 8     RT @sumitbhati2002: Many opposition leaders ar...
# 10    Many opposition leaders are with @narendramodi...
# 11    RT @Joydas: Question in Narendra Modi App wher...
# ...                                                 ...
# 5061  @arunjaitley @FinMinIndia @PMOIndia No machine...
# 5062  @arunjaitley @FinMinIndia @PMOIndia No money i...
# 5097  Currency operater s are still active.#demoneti...
# 5107  @TOIIndiaNews This is what called development....
# 5144  N d modi fans-d true nationalists of the count...
#
#                                              clean_text  \
# 0     @rssurjewala: Critical question: Was PayTM inf...
# 1     @Hemant_80: Did you vote on #Demonetization on...
# 8     @sumitbhati2002: Many opposition leaders are w...
# 10    Many opposition leaders are with @narendramodi...
# 11    @Joydas: Question in Narendra Modi App where P...
# ...                                                 ...
# 5061  @arunjaitley @FinMinIndia @PMOIndia No machine...
# 5062  @arunjaitley @FinMinIndia @PMOIndia No money i...
# 5097  Currency operater s are still active.#demoneti...
# 5107  @TOIIndiaNews This is what called development....
# 5144  N d modi fans-d true nationalists of the count...
#
#                                                 mention            hashtag  \
# 0                                        [@rssurjewala]  [#Demonetization]
# 1                                          [@Hemant_80]  [#Demonetization]
# 8                      [@sumitbhati2002, @narendramodi]  [#Demonetization]
# 10                                      [@narendramodi]  [#Demonetization]
# 11                                            [@Joydas]  [#DeMonetization]
# ...                                                 ...                ...
# 5061  [@arunjaitley, @FinMinIndia, @PMOIndia, @TheOf...                 []
# 5062  [@arunjaitley, @FinMinIndia, @PMOIndia, @CorpB...                 []
# 5097                              [@adhia03, @PMOIndia]  [#demonetization]
# 5107                                    [@TOIIndiaNews]                 []
# 5144                                                 []                 []
#
#       mentions_PM
# 0               1
# 1               1
# 8               1
# 10              1
# 11              1
# ...           ...
# 5061            1
# 5062            1
# 5097            1
# 5107            1
# 5144            1
#
# [1063 rows x 5 columns]

# %%
len(new_df[new_df['mentions_PM']==1])/len(new_df) #21% of the tweets make a reference to the Prime Minister.
# Out:
# 0.20652807460656694

# %% [markdown]
# ### Use of prepositions

# %%
import spacy
nlp= spacy.load('en_core_web_sm', disable= ['ner', 'textcat'])

# %%
text= "@rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure"
from spacy import displacy
displacy.render(nlp(text), style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1011ada7776c417db0e9aff65a54df17-0" class="displacy" width="3375" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">@rssurjewala:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Critical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">question:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">PayTM</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">informed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">about #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Demonetization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">edict</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">PM?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">clearly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">fishy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">requires</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">full</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">disclosure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1011ada7776c417db0e9aff65a54df17-0-0" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1011ada7776c417db0e9aff65a54df17-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1011ada7776c417db0e9aff65a54df17-0-1" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1011ada7776c417db0e9aff65a54df17-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1011ada7776c417db0e9aff65a54df17-0-2" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1011ada7776c417db0e9aff65a54df17-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1011ada7776c417db0e9aff65a54df17-0-3" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1011ada7776c417db0e9aff65a54df17-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,354.0 L928.0,342.0 912.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1011ada7776c417db0e9aff65a54df17-0-4" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1011ada7776c417db0e9aff65a54df17-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displac

# %%
# rule for identifying noun-proposition-noun relationships
def rule(text):

    doc = nlp(text)

    sent = []

    for token in doc:

        # look for prepositions
        if token.pos_=='ADP':

            phrase = ''

            # if its head word is a noun
            if token.head.pos_=='NOUN':

                # append noun and preposition to phrase
                phrase += token.head.text
                phrase += ' '+token.text

                # check the nodes to the right of the preposition
                for right_tok in token.rights:
                    # append if it is a noun or proper noun
                    if (right_tok.pos_ in ['NOUN','PROPN']):
                        phrase += ' '+right_tok.text

                if len(phrase)>2:
                    sent.append(phrase)

    return sent

# %%
# create a df containing sentence and its output for rule
row_list = []

for i in range(len(new_df)):

    sent = new_df.loc[i,'clean_text']
    

    # rule
    output = rule(sent)

    dict1 = {'Tweet':sent,'Output':output}
    row_list.append(dict1)

df_rule = pd.DataFrame(row_list)

# %%
df_rule.head()
# Out:
#                                                Tweet  \
# 0  @rssurjewala: Critical question: Was PayTM inf...
# 1  @Hemant_80: Did you vote on #Demonetization on...
# 2  @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3  @ANI_news: Gurugram (Haryana): Post office emp...
# 4  @satishacharya: Reddy Wedding! @mail_today car...
#
#                          Output
# 0    [edict about, edict by PM]
# 1                            []
# 2                            []
# 3  [patients in demonetization]
# 4                            []

# %%
# select non-empty outputs
df_show = pd.DataFrame(columns=df_rule.columns)

for row in range(len(df_rule)):

    if len(df_rule.loc[row,'Output'])!=0:
        df_show = df_show.append(df_rule.loc[row,:])

# reset the index
df_show.reset_index(inplace = True, drop = True)

# %%
df_show.head(25)
# Out:
#                                                 Tweet  \
# 0   @rssurjewala: Critical question: Was PayTM inf...
# 1   @ANI_news: Gurugram (Haryana): Post office emp...
# 2   @DerekScissors1: Indias #demonetization: #Bla...
# 3   @gauravcsawant: Rs 40 lakh looted from a bank ...
# 4   @Joydeep_911: Calling all Nationalists to join...
# 5   National reform now destroyed even the essence...
# 6   Many opposition leaders are with @narendramodi...
# 7   @Joydas: Question in Narendra Modi App where P...
# 8   @Jaggesh2 Bharat band on 28??Those who  are pr...
# 9   @Atheist_Krishna: The effect of #Demonetizatio...
# 10  @Dipankar_cpiml: The Modi app on #DeMonetizati...
# 11  @pGurus1: #Demonetization The co-operative ban...
# 12  @MahikaInfra: @narendramodi\r\n@Swamy39\r\nThe...
# 13  @kapil_kausik: #Doltiwal I mean #JaiChandKejri...
# 14  @DrGPradhan: 8\r\n\r\nThis tweet of @minimathu...
# 15  roshankar: Harvard's Larry Summers calls #Demo...
# 16  @roshankar: Harvard's Larry Summers calls #Dem...
# 17  @dineshgrao you have 12.5 k followers yet you ...
# 18  @harshkkapoor: #DeMonetization survey results ...
# 19  @rohanmlw: #demonetization eye opener video bt...
# 20  @Punitspeaks: Survey result so far by @PMOIndi...
# 21  @nmleo1: Is #ModiSarkar 's #achedin campaign o...
# 22  @pGurus1: CPI-M opposes Co-op Banks in West Be...
# 23  roshankar: Harvard's Larry Summers calls #Demo...
# 24  @pGurus1: #Demonetization move of Modi; Who is...
#
#                                                Output
# 0                          [edict about, edict by PM]
# 1                        [patients in demonetization]
# 2                          [disease via @ambazaarmag]
# 3                                  [bank in Kishtwar]
# 4   [benefits of Demonetization, Demonetization am...
# 5                                  [essence of sagan]
# 6                                    [b'coz of party]
# 7                                   [Question in App]
# 8                                           [band on]
# 9                          [effect of Demonetization]
# 10                            [app on DeMonetization]
# 11                                 [sector in Kerala]
# 12                        [success of Demonetization]
# 13                               [JaiChandKejriwal #]
# 14                                    [tweet of BIBI]
# 15          [Demonetization as policy, policy with o]
# 16  [Demonetization as policy, policy with impact,...
# 17                                 [likes for tweets]
# 18             [response in fight, fight against @na]
# 19                                            [ve of]
# 20                                      [response in]
# 21                       [campaign on demonetization]
# 22                                  [Banks in Bengal]
# 23          [Demonetization as policy, policy with o]
# 24                [move of Modi, coverage of parties]

# %%
# separate noun, preposition and noun

prep_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_show)):

    # sentence containing the output
    sentence = df_show.loc[i,'Tweet']
    # output of the sentence
    output = df_show.loc[i,'Output']

    # iterating over all the outputs from the sentence
    for sent in output:

        # separate subject, verb and object
        n1, p, n2 = sent.split()[0], sent.split()[1], sent.split()[2:]

        # append to list, along with the sentence
        dis_dict = {'Tweet':sentence,'Noun1':n1,'Preposition':p,'Noun2':n2}
        dis_list.append(dis_dict)

        # counting the number of sentences containing the verb
        prep = sent.split()[1]
        if prep in prep_dict:
            prep_dict[prep]+=1
        else:
            prep_dict[prep]=1

df_sep= pd.DataFrame(dis_list)

# %%
df_sep[df_sep['Preposition']=='for'] #wher the proposition is for
# Out:
#                                                   Tweet    Noun1 Preposition  \
# 22    @dineshgrao you have 12.5 k followers yet you ...    likes         for
# 33    @ModiBharosa: Huge support for PM @narendramod...  support         for
# 94    @MDiplomacyWORLD: Acid test for #Modi and #BJP...     test         for
# 95    Acid test for #Modi and #BJP: #Demonetization ...     test         for
# 109   @SriSri  Ravi Shankar roots for #demonetizatio...    roots         for
# ...                                                 ...      ...         ...
# 3286  Demonetization: Another chance for deposit of ...   chance         for
# 3291  @mostlyeconomics: Did India get the idea for i...     idea         for
# 3363  #India #oil demand shrinks for third month ami...  shrinks         for
# 3399  @HDFCBank_Cares The issue is not shortage but ...   charge         for
# 3408  @thehill To The Hill. Shame on you for your an...    Shame         for
#
#                  Noun2
# 22            [tweets]
# 33                [PM]
# 94              [Modi]
# 95              [Modi]
# 109   [demonetization]
# ...                ...
# 3286         [deposit]
# 3291  [demonetization]
# 3363           [month]
# 3399      [withdrawal]
# 3408  [demonetization]
#
# [208 rows x 4 columns]

# %%
df_sep[df_sep['Preposition']=='against'] #where the proposition is against
# Out:
#                                                Sentence      Noun1  \
# 24    @harshkkapoor: #DeMonetization survey results ...      fight
# 37    @bhaiyyajispeaks: Here @sardesairajdeep strugg...     answer
# 47    @ashu3page: A man shaved his head at Jantar-Ma...    protest
# 67    @IndiaFactsOrg: #Demonetization: The Ultimate ...     Weapon
# 112   Do you support the Opposition's agitation agai...  agitation
# ...                                                 ...        ...
# 3091  #India #National CBI files case against manage...       case
# 3100  CBI files case against managers of Bank of Mah...       case
# 3103  CBI files case against managers of Bank of Mah...       case
# 3114  I think pm should take action against pakistan...     action
# 3131  Demonetization has created immense anger among...     masses
#
#      Preposition             Noun2
# 24       against             [@na]
# 37       against  [Demonetization]
# 47       against  [Demonetization]
# 67       against         [economy]
# 112      against  [demonetization]
# ...          ...               ...
# 3091     against        [managers]
# 3100     against        [managers]
# 3103     against        [managers]
# 3114     against              [ur]
# 3131     against            [Modi]
#
# [89 rows x 4 columns]
